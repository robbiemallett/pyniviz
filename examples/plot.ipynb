# %%
import sys
sys.path.append('..')
from pyniviz import main
import datetime

# %% [markdown]
# # Settings

# %%
start_date = datetime.datetime(year=2020,
                               month=1,
                               day=29)
end_date = datetime.datetime(year=2020,
                             month=2,
                             day=8)

# %% [markdown]
# # Plot temperature

# %%
main.plot_pro('sample.pro',
                 variable= 'element temperature (degC)',
                 ymin=400,
                 ymax=415,
                 xmin=start_date,
                 xmax=end_date,
                 file_name='temp_fig.png',
                 c_scheme='Reds',
                 yax_shift=400)

# %% [markdown]
# # Plot grain shape

# %%
main.plot_pro('sample.pro',
                 variable= 'grain type',
                 ymin=400,
                 ymax=415,
                 xmin=start_date,
                 xmax=end_date,
                 file_name='gt_fig.png',
                 yax_shift=400)

# %% [markdown]
# # Plot timeseries

# %%
main.plot_smet('sample.smet', 'TA')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-24e3fe92fb8f> in <module>
# ----> 1 main.plot_smet('sample.smet', 'TA')
#
# ~/Documents/pyniviz/pyniviz/main.py in plot_smet(path, var)
#      59 def plot_smet(path, var):
#      60
# ---> 61     df = read_smet(path, var)
#      62
#      63     df.plot()
#
# ~/Documents/pyniviz/pyniviz/tools.py in read_smet(path, var)
#     580     df = pd.DataFrame(ts, index=time)
#     581
# --> 582     if var == "MS_Redeposit_dHS" or var_str == "MS_Redeposit_dRHO":
#     583
#     584         df[df == -999] = 0
#
# NameError: name 'var_str' is not defined
